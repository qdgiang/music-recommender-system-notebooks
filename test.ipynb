# %%
import pandas as pd
#from checker import *

# %%
song_data = pd.read_csv('data/df_songs.csv')
song_data.shape
# Out:
# (2000000, 7)

# %%
# group into title. Show total listen_count, and show song_id, release, artist_name, year. Show title as well
meta_data = song_data.groupby('title').agg({'listen_count': 'sum', 'song_id': 'first', 'release': 'first', 'artist_name': 'first', 'year': 'first'}).sort_values('listen_count', ascending=False)

# %%
meta_data
# Out:
#                                                     listen_count  \
# title
# You're The One                                             54915
# Undo                                                       49253
# Revelry                                                    41418
# Horn Concerto No. 4 in E flat K495: II. Romance...         31153
# Sehr kosmisch                                              31036
# ...                                                          ...
# Summer In Dixie (LP Version)                                  76
# Slan Le Maige                                                 75
# Robot Rock (Soulwax Remix)                                    73
# Traveling Man                                                 73
# clouding                                                      71
#
#                                                                song_id  \
# title
# You're The One                                      SOBONKR12A58A7A7E0
# ...

# %%
# export meta_data to csv
meta_data.to_csv('data/meta_data.csv')

# %%
songs
# Out:
# array(['The Cove', 'Entre Dos Aguas', 'Stronger', ..., 'Super Honeymoon',
#        'Compañera',
#        "Baby [You've Got What It Takes] [with Sharon Jones & the Dap-Kings]"],
#       dtype=object)

# %%
song_data.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
ARTIST = "Coldplay"
SONG = "The Scientist"

# %%
# get the first row of that have the sone name and song artist occured
song_data[song_data.artist_name == ARTIST][song_data.title == SONG].song_id.values
# Out:
# /tmp/ipykernel_62548/1837793262.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   song_data[song_data.artist_name == ARTIST][song_data.title == SONG].song_id.values
# array(['SOKLRPJ12A8C13C3FE', 'SOKLRPJ12A8C13C3FE', 'SOKLRPJ12A8C13C3FE',
#        ..., 'SOKLRPJ12A8C13C3FE', 'SOKLRPJ12A8C13C3FE',
#        'SOKLRPJ12A8C13C3FE'], dtype=object)

# %%
song_data[song_data.artist_name == 'Coldplay'].title.value_counts()

# check if variant of artist name is in the data
#song_data[song_data.artist_name.str.contains('Cold')].title.value_counts()
# Out:
# The Scientist                             3372
# Clocks                                    3139
# Yellow                                    2829
# Fix You                                   2246
# Shiver                                    1385
# In My Place                               1242
# Speed Of Sound                            1205
# Don't Panic                                809
# Sparks                                     685
# Lost!                                      608
# Life In Technicolor ii                     585
# Brothers & Sisters                         578
# Strawberry Swing                           564
# Trouble                                    506
# A Rush Of Blood To The Head                484
# God Put A Smile Upon Your Face             472
# Politik                                    461
# Warning Sign                               422
# For You                                    397
# One I Love                                 394
# ...

# %%
song_data[song_data.artist_name == 'OneRepublic'].title.value_counts()
# Out:
# Secrets                  5841
# All The Right Moves      2028
# Apologize                 656
# Good Life                 363
# Say (All I Need)          288
# Marchin On                210
# Mercy                     186
# Come Home                 181
# All This Time             177
# Everybody Loves Me        176
# Someone To Save You       175
# Made For You              157
# Waking Up                 136
# Lullaby                   132
# Fear                      131
# All We Are                128
# Missing Persons 1 & 2     118
# All Fall Down              99
# Goodbye_ Apathy            80
# Dreaming Out Loud          79
# Tyrant                     68
# Prodigal                   67
# Name: title, dtype: int64

# %%
song_data[song_data.artist_name == 'Maroon 5'].title.value_counts()
# Out:
# Won't Go Home Without You    402
# Makes Me Wonder              372
# Sunday Morning               369
# Wake Up Call                 364
# Harder To Breathe            321
# Not Falling Apart            206
# Better That We Break         186
# Nothing Lasts Forever        172
# Until You're Over Me         151
# Little Of Your Time          147
# Story                        133
# Infatuation                  125
# Losing My Mind               125
# Can't Stop                   116
# Kiwi                          93
# Shiver                        86
# The Way I Was                 79
# Name: title, dtype: int64

# %%
song_data[song_data.artist_name == 'Snow Patrol'].title.value_counts()
# Out:
# Chasing Cars                        657
# Crack The Shutters                  431
# Hands Open                          372
# Run                                 351
# You Could Be Happy                  316
# Just Say Yes                        279
# The Lightning Strike                221
# Shut Your Eyes                      205
# Make This Go On Forever             180
# Chocolate                           161
# Signal Fire                         149
# If There's a Rocket Tie Me To It    111
# It's Beginning To Get To Me          97
# The Planets Bend Between Us          93
# The Finish Line                      90
# In My Arms                           88
# Lifeboats                            87
# Name: title, dtype: int64

# %%
song_data[song_data.artist_name == 'Fall Out Boy'].title.value_counts()
# Out:
# Dance_ Dance                                                                  466
# Sugar_ We're Goin Down                                                        448
# This Ain't A Scene_ It's An Arms Race                                         321
# Thnks fr th Mmrs                                                              268
# Beat It                                                                       213
# Grand Theft Autumn/Where Is Your Boy (Album Version)                          117
# The Carpal Tunnel Of Love                                                     103
# Calm Before The Storm (Album Version)                                         101
# I'm Like A Lawyer With The Way I'm Always Trying To Get You Off (Me & You)     97
# A Little Less Sixteen Candles_ A Little More "Touch Me                         97
# Hum Hallelujah                                                                 96
# ...

# %%
song_data[song_data.artist_name == 'Radiohead'].title.value_counts()
# Out:
# Creep (Explicit)                            2839
# Karma Police                                1381
# House Of Cards                               570
# 15 Step                                      568
# (Nice Dream)                                 497
# Weird Fishes/Arpeggi                         492
# Everything In Its Right Place                461
# Jigsaw Falling Into Place                    458
# Talk Show Host                               450
# Exit Music (For A Film)                      414
# Let Down                                     397
# Just                                         366
# Faust Arp                                    312
# Kid A                                        284
# Subterranean Homesick Alien                  281
# How To Disappear Completely                  279
# There_ There                                 274
# Planet Telex                                 251
# I Might Be Wrong                             201
# ...

# %%
song_artist = song_data['artist_name'].unique()

# %%
song_title = song_data['title'].unique()

# %%
song_data['title'].value_counts()
# Out:
# Sehr kosmisch                     8277
# Undo                              7032
# Dog Days Are Over (Radio Edit)    6949
# You're The One                    6729
# Revelry                           6145
#                                   ...
# Scared                              51
# Historia Del Portero                51
# Don´t Leave Me Now                  50
# No Creo En El Jamas                 48
# Ghosts (Toxic Avenger Mix)          48
# Name: title, Length: 9567, dtype: int64

# %%
s=song_data['title'].value_counts().nlargest(10)
print("songs to recommend based on popularity\n",s)
# Out:
# songs to recommend based on popularity
#  Sehr kosmisch                                                          8277
# Undo                                                                   7032
# Dog Days Are Over (Radio Edit)                                         6949
# You're The One                                                         6729
# Revelry                                                                6145
# Secrets                                                                5841
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)    5385
# Fireflies                                                              4795
# Hey_ Soul Sister                                                       4758
# Tive Sim                                                               4548
# Name: title, dtype: int64

# %%
users = song_data['user_id'].unique()

# %%
len(users)
# Out:
# 76353

# %%
song_data.drop_duplicates(['user_id','title','artist_name'], inplace=True)
song_data.reset_index(drop=True, inplace=True)

# %%
song_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1998249 entries, 0 to 1998248
# Data columns (total 7 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   user_id       object
#  1   song_id       object
#  2   listen_count  int64
#  3   title         object
#  4   release       object
#  5   artist_name   object
#  6   year          int64
# dtypes: int64(2), object(5)
# memory usage: 106.7+ MB

# %%
song_pivot=song_data.pivot_table(index='user_id',columns='song_id',values='listen_count')

# %%
song_pivot=song_pivot.fillna(0)

# %%
# Get the song title from the song id
song_title = song_data.set_index('song_id')['title'].to_dict()
song_title
# Out:
# {'SOAKIMP12A8C130995': 'The Cove',
#  'SOBBMDR12A8C13253B': 'Entre Dos Aguas',
#  'SOBXHDL12A81C204C0': 'Stronger',
#  'SOBYHAJ12A6701BF1D': 'Constellations',
#  'SODACBL12A8C13C273': 'Learn To Fly',
#  'SODDNQT12A6D4F5F7E': "Apuesta Por El Rock 'N' Roll",
#  'SODXRTY12AB0180F3B': 'Paper Gangsta',
#  'SOFGUAY12AB017B0A8': 'Stacked Actors',
#  'SOFRQTD12A81C233C0': 'Sehr kosmisch',
#  'SOHQWYZ12A6D4FA701': "Heaven's gonna burn your eyes",
#  'SOIYTOA12A6D4F9A23': 'Let It Be Sung',
#  'SOIZAZL12A6701C53B': "I'll Be Missing You (Featuring Faith Evans & 112)(Album Version)",
#  'SOJNNUA12A8AE48C7A': 'Love Shack',
#  'SOJPFQG12A58A7833A': 'Clarity',
#  'SOKRIMP12A6D4F5DA3': "I?'m A Steady Rollin? Man",
#  'SOLLGNU12AF72A4D4F': 'The Old Saloon',
#  'SOMGIYR12AB0187973': 'Behind The Sea [Live In Chicago]',
#  'SOMLMKI12A81C204BC': 'Champion',
#  'SOMSQJY12A8C138539': 'Breakout',
#  'SONSAEZ12A8C138D7A': 'Ragged Wood',
#  'SOOKGRB12A8C13CD66': 'Mykonos',
# ...

# %%
SONG_ID = 'SOTFATN12A6D4FA74D'
print("Song title for song id {} is {}".format(SONG_ID, song_title[SONG_ID]))
# Out:
# Song title for song id SOTFATN12A6D4FA74D is The Christmas Song  (LP Version)

# %%
song_pivot["SOTFATN12A6D4FA74D"].value_counts() # Check
# Out:
# 0.0     76249
# 1.0        48
# 2.0        12
# 5.0        11
# 6.0         7
# 3.0         7
# 7.0         4
# 4.0         3
# 8.0         3
# 10.0        2
# 17.0        1
# 25.0        1
# 33.0        1
# 19.0        1
# 16.0        1
# 21.0        1
# 11.0        1
# Name: SOTFATN12A6D4FA74D, dtype: int64

# %%
from sklearn.neighbors import NearestNeighbors
knn=NearestNeighbors(n_neighbors=10,metric='cosine')
Model=knn.fit(song_pivot)
